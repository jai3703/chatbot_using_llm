# %%
import pandas as pd
import numpy as np
from nselib import capital_market
import warnings
warnings.filterwarnings("ignore")
import datetime
from jugaad_data.nse import stock_df
import os
from dotenv import load_dotenv

# %%
nifty_top_500 = pd.read_csv("ind_nifty500list.csv")
nifty_top_500
# Out:
#                            Company Name                           Industry  \
# 0                      360 ONE WAM Ltd.                 Financial Services
# 1                         3M India Ltd.                        Diversified
# 2                        ABB India Ltd.                      Capital Goods
# 3                              ACC Ltd.             Construction Materials
# 4                  AIA Engineering Ltd.                      Capital Goods
# ..                                  ...                                ...
# 495  Zee Entertainment Enterprises Ltd.  Media Entertainment & Publication
# 496             Zensar Technolgies Ltd.             Information Technology
# 497                         Zomato Ltd.                  Consumer Services
# 498             Zydus Lifesciences Ltd.                         Healthcare
# 499                eClerx Services Ltd.                           Services
#
#          Symbol Series     ISIN Code
# ...

# %% [markdown]
# # steps to pull data1
# 1. every month will check/update nifty 500 list- manually
# 2. for 1st time

# %%
today = datetime.date.today()
previous_year = today.year -1
today_last_year = today.replace(year = previous_year)
today_last_year
# Out:
# datetime.date(2023, 12, 22)

# %%
def pull_stock_data(stock_symbol:str) -> pd.DataFrame:
    today = datetime.date.today()
    previous_year = today.year -1
    today_last_year = today.replace(year = previous_year)
    data = stock_df(symbol=stock_symbol, from_date=today_last_year,
            to_date=today, series="EQ")
    
    return data

pull_stock_data("ABB")
# Out:
#           DATE SERIES     OPEN     HIGH      LOW  PREV. CLOSE      LTP  \
# 0   2024-12-20     EQ  7359.80  7407.45  6886.00      7351.90  6940.00
# 1   2024-12-19     EQ  7620.00  7620.00  7335.10      7657.15  7343.00
# 2   2024-12-18     EQ  7812.05  7814.75  7620.50      7817.45  7663.50
# 3   2024-12-17     EQ  7890.35  7960.00  7781.00      7890.35  7800.00
# 4   2024-12-16     EQ  7703.25  7943.75  7689.30      7703.25  7884.80
# ..         ...    ...      ...      ...      ...          ...      ...
# 243 2023-12-29     EQ  4669.00  4688.00  4618.60      4642.95  4671.00
# 244 2023-12-28     EQ  4746.70  4765.40  4622.00      4733.60  4635.30
# 245 2023-12-27     EQ  4799.95  4822.90  4724.00      4771.35  4741.00
# 246 2023-12-26     EQ  4771.35  4824.00  4747.25      4759.00  4778.05
# 247 2023-12-22     EQ  4723.00  4765.00  4686.10      4684.50  4753.00
#
#        CLOSE     VWAP    52W H   52W L  VOLUME         VALUE  NO OF TRADES  \
# ...

# %%
nifty_top_500.columns
# Out:
# Index(['Company Name', 'Industry', 'Symbol', 'Series', 'ISIN Code'], dtype='object')

# %%
master_data = pd.DataFrame()
for stock_symbol in nifty_top_500.Symbol.unique():
    try:
        #stock = 'TATAMOTORS'
        print(stock_symbol)
        data = pull_stock_data(stock_symbol=stock_symbol)
        master_data = pd.concat([master_data,data],axis=0)
    except:
        pass

master_data
# Out:
# 360ONE
# 3MINDIA
# ABB
# ACC
# AIAENG
# APLAPOLLO
# AUBANK
# AADHARHFC
# AARTIIND
# AAVAS
# ABBOTINDIA
# ACE
# ADANIENSOL
# ADANIENT
# ADANIGREEN
# ADANIPORTS
# ADANIPOWER
# ATGL
# AWL
# ABCAPITAL
# ABFRL
# ABREL
# ABSLAMC
# AEGISLOG
# AFFLE
# AJANTPHARM
# AKUMS
# APLLTD
# ALKEM
# ALKYLAMINE
# ALOKINDS
# ARE&M
# AMBER
# AMBUJACEM
# ANANDRATHI
# ANANTRAJ
# ANGELONE
# APARINDS
# APOLLOHOSP
# APOLLOTYRE
# APTUS
# ACI
# ASAHIINDIA
# ASHOKLEY
# ASIANPAINT
# ASTERDM
# ASTRAZEN
# ASTRAL
# ATUL
# AUROPHARMA
# AVANTIFEED
# DMART
# AXISBANK
# BASF
# BEML
# BLS
# BSE
# BAJAJ-AUTO
# BAJFINANCE
# BAJAJFINSV
# BAJAJHLDNG
# BALAMINES
# BALKRISIND
# BALRAMCHIN
# BANDHANBNK
# BANKBARODA
# BANKINDIA
# MAHABANK
# BATAINDIA
# BAYERCROP
# BERGEPAINT
# BDL
# BEL
# BHARATFORG
# BHEL
# BPCL
# BHARTIARTL
# BHARTIHEXA
# BIKAJI
# BIOCON
# BIRLACORPN
# BSOFT
# BLUEDART
# BLUESTARCO
# BBTC
# BOSCHLTD
# BRIGADE
# BRITANNIA
# MAPMYINDIA
# CCL
# CESC
# CGPOWER
# CIEINDIA
# CRISIL
# CAMPUS
# CANFINHOME
# CANBK
# ...

# %%
# Load environment variables from .env file
load_dotenv()

# Access the database URL
db_url = os.getenv('DB_URL')

# Print to confirm (remove in production for security)
print(f"Database URL: {db_url}")
# Out:
# Database URL: postgresql://indian_stock_price_owner:pNtS0PQz2brv@ep-square-frog-a5a60p1q.us-east-2.aws.neon.tech/indian_stock_price?sslmode=require

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# Define table name
table_name = "nifty_top_500_stocks"

# Database connection string
db_url = db_url

# Create an SQLAlchemy engine
engine = create_engine(db_url)

# Write data to the PostgreSQL table
try:
    master_data.to_sql(table_name, engine, index=False, if_exists='replace')  # 'replace' overwrites table if it exists
    print(f"Data successfully written to table '{table_name}' in PostgreSQL!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Data successfully written to table 'nifty_top_500_stocks' in PostgreSQL!
